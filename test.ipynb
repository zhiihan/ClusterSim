# %%
import rustworkx as rx
from rustworkx.visualization import mpl_draw
from cluster_sim.simulator import ClusterState

g = rx.generators.path_graph(5)
mpl_draw(g)
# ClusterState(g)

for index in g.edge_list():
    print(index)
# Out:
# (0, 1)
# (1, 2)
# (2, 3)
# (3, 4)

# %%
G = ClusterState(graph = g)


for i in range(5):
    G.H(i)

G
# Out:
# +XIIII
# +IXIII
# +IIXII
# +IIIXI
# +IIIIX
