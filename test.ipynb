# %%
from cluster_sim.app import BrowserState
import jsons

# %%
b = BrowserState()

json_str = jsons.dumps(b)
json_str
# Out:
# '{"camera_state": {"scene.camera": {"up": {"x": 0, "y": 0, "z": 1}, "center": {"x": 0, "y": 0, "z": 0}, "eye": {"x": 1.4, "y": 1.4, "z": 1.3}, "projection": {"type": "perspective"}}}, "log": "", "move_list": "", "offset": [0, 0, 0], "p": 0.09, "path_clicks": 0, "removed_nodes": [], "seed": null, "shape": [4, 4, 4], "xmax": 4, "xoffset": 0, "ymax": 4, "yoffset": 0, "zmax": 4, "zoffset": 0}'

# %%
obj = jsons.loads(json_str, cls=BrowserState)
obj
# Out:
# BrowserState(xmax=4, ymax=4, zmax=4, shape=(4, 4, 4), p=0.09, seed=None, path_clicks=0, removed_nodes=set(), log='', move_list='', camera_state={'scene.camera': {'up': {'x': 0, 'y': 0, 'z': 1}, 'center': {'x': 0, 'y': 0, 'z': 0}, 'eye': {'x': 1.4, 'y': 1.4, 'z': 1.3}, 'projection': {'type': 'perspective'}}}, offset=(0, 0, 0))
